# %%
import pandas as pd
data2007 = pd.read_csv(r'C:\Users\laurie.gellhorn\OneDrive - WPP Cloud\Desktop\CNS\EMEA-CNS-2007.csv',encoding='utf16')
data2008 = pd.read_csv(r'C:\Users\laurie.gellhorn\OneDrive - WPP Cloud\Desktop\CNS\EMEA-CNS-2008.csv',encoding='utf16')
data2009 = pd.read_csv(r'C:\Users\laurie.gellhorn\OneDrive - WPP Cloud\Desktop\CNS\EMEA-CNS-2009.csv',encoding='utf16')
data2010 = pd.read_csv(r'C:\Users\laurie.gellhorn\OneDrive - WPP Cloud\Desktop\CNS\EMEA-CNS-2010.csv',encoding='utf16')
data2011 = pd.read_csv(r'C:\Users\laurie.gellhorn\OneDrive - WPP Cloud\Desktop\CNS\EMEA-CNS-2011.csv',encoding='utf16')
data2012 = pd.read_csv(r'C:\Users\laurie.gellhorn\OneDrive - WPP Cloud\Desktop\CNS\EMEA-CNS-2012.csv',encoding='utf16')
data2013 = pd.read_csv(r'C:\Users\laurie.gellhorn\OneDrive - WPP Cloud\Desktop\CNS\EMEA-CNS-2013.csv',encoding='utf16')
data2014 = pd.read_csv(r'C:\Users\laurie.gellhorn\OneDrive - WPP Cloud\Desktop\CNS\EMEA-CNS-2014.csv',encoding='utf16')
data2015 = pd.read_csv(r'C:\Users\laurie.gellhorn\OneDrive - WPP Cloud\Desktop\CNS\EMEA-CNS-2015.csv',encoding='utf16', low_memory=False)
data2016 = pd.read_csv(r'C:\Users\laurie.gellhorn\OneDrive - WPP Cloud\Desktop\CNS\EMEA-CNS-2016.csv',encoding='utf16', low_memory=False)
data2017 = pd.read_csv(r'C:\Users\laurie.gellhorn\OneDrive - WPP Cloud\Desktop\CNS\EMEA-CNS-2017.csv',encoding='utf16', low_memory=False)
data2018 = pd.read_csv(r'C:\Users\laurie.gellhorn\OneDrive - WPP Cloud\Desktop\CNS\EMEA-CNS-2018.csv',encoding='utf16', low_memory=False)
data2019 = pd.read_csv(r'C:\Users\laurie.gellhorn\OneDrive - WPP Cloud\Desktop\CNS\EMEA-CNS-2019.csv',encoding='utf16', low_memory=False)
data2020 = pd.read_csv(r'C:\Users\laurie.gellhorn\OneDrive - WPP Cloud\Desktop\CNS\EMEA-CNS-2020.csv',encoding='utf16', low_memory=False)
data2021 = pd.read_csv(r'C:\Users\laurie.gellhorn\OneDrive - WPP Cloud\Desktop\CNS\EMEA-CNS-2021.csv',encoding='utf16', low_memory=False)
data2022 = pd.read_csv(r'C:\Users\laurie.gellhorn\OneDrive - WPP Cloud\Desktop\CNS\EMEA-CNS-2022.csv',encoding='utf16', low_memory=False)
data2023 = pd.read_csv(r'C:\Users\laurie.gellhorn\OneDrive - WPP Cloud\Desktop\CNS\EMEA-CNS-2023.csv',encoding='utf16', low_memory=False)
Dataframe1 = pd.concat( (data2007,data2008,data2009,data2010,data2011,data2012,data2013,data2014,data2015,data2016,data2017,data2018,data2019,data2020,data2021,data2022,data2023), ignore_index=True)

# %%
Dataframe1.to_csv(r"C:\Users\laurie.gellhorn\OneDrive - WPP Cloud\Desktop\Projects\Confidence model\Fresh start.csv")

# %% [markdown]
# #Here I opened the CSV up in Excel and deleted some empty rows, and moved the row headers to their correct place. and then re-uploaded to Jupyter Notebooks.

# %%
df = pd.read_csv(r"C:\Users\laurie.gellhorn\OneDrive - WPP Cloud\Desktop\Projects\Confidence model\Fresh start\Fresh start.csv")

# %%
df = df[~df.CLIENT.isin(["CLIENT=CLITOT", "CLIENT=TOTCLI", "CLIENT=DESTOT", "CLIENT=LOCTOT"])]
print(df)
# Out:
#               AC          PE            RU          CLIENT      Client Name  \
# 0       AC=74730  PE=2007.01    RU=IMBEAG1    CLIENT=D2200   Bro Alken Maes
# 1       AC=74730  PE=2007.01    RU=IMBEAG1   CLIENT=T-CITI  Citigroup Total
# 2       AC=74730  PE=2007.01    RU=IMBEAG1   CLIENT=T-FORD  Ford/FDAF Total
# 3       AC=74730  PE=2007.01    RU=IMBEAG1  CLIENT=T-LUFTH  Lufthansa Total
# 4       AC=74730  PE=2007.01    RU=IMBEAG1   CLIENT=T-MSFT  Microsoft Total
# ...          ...         ...           ...             ...              ...
# 899994  AC=74770  PE=2023.12  RU=WTUKSALFP   CLIENT=NEWBUS     New business
# 899995  AC=74770  PE=2023.12  RU=WTUKSALFP   CLIENT=OTHCLI    Other clients
# 899999  AC=74770  PE=2023.12    RU=WTUKSAT   CLIENT=IGROUP          I/Group
# 900001  AC=74770  PE=2023.12    RU=WTUKSAT   CLIENT=NEWBUS     New business
# 900002  AC=74770  PE=2023.12    RU=WTUKSAT   CLIENT=OTHCLI    Other clients
#
# ...

# %%
values=["AC=74730","AC=74770"]
df3 = df3[df3["AC_x"].isin(values)]

# %%
Office_Structure = pd.read_excel(r"C:\Users\laurie.gellhorn\OneDrive - WPP Cloud\Desktop\Projects\Confidence model\Office Structure.xlsx")

# %%
#Here I merged on Office Structure.

# %%
df2 = pd.merge(df,Office_Structure,how="left",on="RU")
df2.head(100)
# Out:
#           AC          PE           RU          CLIENT      Client Name  \
# 0   AC=74730  PE=2007.01   RU=IMBEAG1    CLIENT=D2200   Bro Alken Maes
# 1   AC=74730  PE=2007.01   RU=IMBEAG1   CLIENT=T-CITI  Citigroup Total
# 2   AC=74730  PE=2007.01   RU=IMBEAG1   CLIENT=T-FORD  Ford/FDAF Total
# 3   AC=74730  PE=2007.01   RU=IMBEAG1  CLIENT=T-LUFTH  Lufthansa Total
# 4   AC=74730  PE=2007.01   RU=IMBEAG1   CLIENT=T-MSFT  Microsoft Total
# ..       ...         ...          ...             ...              ...
# 95  AC=74730  PE=2007.01   RU=IMNLBLR    CLIENT=D0220          Esselte
# 96  AC=74730  PE=2007.01   RU=IMNLBLR    CLIENT=D0426         Nintendo
# 97  AC=74730  PE=2007.01   RU=IMNLBLR   CLIENT=T-VODA   Vodafone Total
# 98  AC=74730  PE=2007.01  RU=IMPTFUT1    CLIENT=D0060          Bacardi
# 99  AC=74730  PE=2007.01  RU=IMPTFUT1    CLIENT=D0554          Siemens
#
#                    Client Industry                  Client Sub-Industry  \
# ...

# %%
df2["RUCLIENT"] = df2["RU"] + df2["CLIENT"]

# %%
ALLLOCCLI = pd.read_excel(r"C:\Users\laurie.gellhorn\OneDrive - WPP Cloud\Desktop\Projects\Confidence model\ALLLOCCLI.xlsx")
ALLLOCCLI.head()
# Out:
#              RU        CLIENT        AC  Unnamed: 3  \
# 0  RU=BMAEDATHU  CLIENT=L0001  AC=74770         NaN
# 1  RU=BMAEDATHU  CLIENT=L0002  AC=74770         NaN
# 2  RU=BMAEDATHU  CLIENT=L0003  AC=74770         NaN
# 3  RU=BMAEDATHU  CLIENT=L0004  AC=74770         NaN
# 4  RU=BMAEDATHU  CLIENT=L0005  AC=74770         NaN
#
#                         Client Name Client Industry
# 0          Polaris Public Relations           Dubai
# 1  International copper association           Dubai
# 2                           Edelman           Dubai
# 3                          Al Shaya           Dubai
# 4              Al Zorah Development           Dubai

# %%
ALLLOCCLI["RUCLIENT"] = ALLLOCCLI["RU"] + ALLLOCCLI["CLIENT"]

# %%
df3 = pd.merge(df2,ALLLOCCLI, on='RUCLIENT', how='left')
df3.head()
# Out:
#        AC_x          PE        RU_x        CLIENT_x    Client Name_x  \
# 0  AC=74730  PE=2007.01  RU=IMBEAG1    CLIENT=D2200   Bro Alken Maes
# 1  AC=74730  PE=2007.01  RU=IMBEAG1   CLIENT=T-CITI  Citigroup Total
# 2  AC=74730  PE=2007.01  RU=IMBEAG1   CLIENT=T-FORD  Ford/FDAF Total
# 3  AC=74730  PE=2007.01  RU=IMBEAG1  CLIENT=T-LUFTH  Lufthansa Total
# 4  AC=74730  PE=2007.01  RU=IMBEAG1   CLIENT=T-MSFT  Microsoft Total
#
#   Client Industry_x Client Sub-Industry          FL  Actual  Budget  ...  \
# 0               CPG  Drinks - Alcoholic  FL=MAN-PER     NaN     NaN  ...
# 1               NaN                 NaN  FL=MAN-PER     NaN     NaN  ...
# 2               NaN                 NaN  FL=MAN-PER     NaN     NaN  ...
# 3               NaN                 NaN  FL=MAN-PER     NaN     NaN  ...
# 4               NaN                 NaN  FL=MAN-PER     NaN     NaN  ...
#
#    Proforma           Individual Unit  Management Unit  \
# ...

# %%
df3['Client Name_x'] = df3['Client Name_x'].mask(df3['Client Name_x'].str.contains('Local'), df3['Client Name_y'])
